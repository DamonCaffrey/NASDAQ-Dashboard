# %%
from bs4 import BeautifulSoup as bs
import requests as rq

import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Generated Files//Filtered_nasdaq.csv")

df
# Out:
#       Unnamed: 0 Symbol                                              Name  \
# 0              3   AACG  ATA Creativity Global American Depositary Shares
# 1              4   AACI           Armada Acquisition Corp. I Common Stock
# 2              7   AADI                 Aadi Bioscience Inc. Common Stock
# 3             12    AAL         American Airlines Group Inc. Common Stock
# 4             16   AAME        Atlantic American Corporation Common Stock
# ...          ...    ...                                               ...
# 3576        7810   ZVRA              Zevra Therapeutics Inc. Common Stock
# 3577        7811   ZVSA            ZyVersa Therapeutics Inc. Common Stock
# 3578        7813   ZYME                       Zymeworks Inc. Common Stock
# 3579        7814   ZYNE         Zynerba Pharmaceuticals Inc. Common Stock
# 3580        7815   ZYXI                           Zynex Inc. Common Stock
#
#         Market Cap        Country  IPO Year                  Sector  \
# ...

# %%
df.describe(include="all")
# Out:
#          Unnamed: 0 Symbol                                              Name  \
# count   3581.000000   3581                                              3581
# unique          NaN   3581                                              3581
# top             NaN   AACG  ATA Creativity Global American Depositary Shares
# freq            NaN      1                                                 1
# mean    3961.342642    NaN                                               NaN
# std     2257.565828    NaN                                               NaN
# min        3.000000    NaN                                               NaN
# 25%     1981.000000    NaN                                               NaN
# 50%     4028.000000    NaN                                               NaN
# 75%     5910.000000    NaN                                               NaN
# max     7815.000000    NaN                                               NaN
#
# ...

# %%
li = []
start = 0
end = df.shape[0]
# start = 5
# end = 25


for i in range(start, end):
    
    temp_li = []
    time.sleep(0.1)
    
    base_url = "https://finance.yahoo.com/quote/"
    symb = df["Symbol"].iloc[i]
    
    url = base_url + symb + "/profile?p=ABST"
    response = rq.get(url, headers={"User-Agent":"Mozilla/5.0"})
    
    page = response.text
    soup = bs(page)
    
    
    temp_li.append(symb)
    for x in soup.find_all("span", class_='Fw(600)'):
        temp_li.append(x.text)
    
    li.append(temp_li)

# %%
li
# Out:
# [['AACG',
#   'Follow',
#   'Consumer Defensive',
#   'Education & Training Services',
#   '536'],
#  ['AACI', 'Follow', 'Financial Services', 'Shell Companies', ''],
#  ['AADI', 'Follow', 'Healthcare', 'Biotechnology', '79'],
#  ['AAL', 'Follow', 'Industrials', 'Airlines', '129,700'],
#  ['AAME', 'Follow', 'Financial Services', 'Insurance—Life', '138'],
#  ['AAOI', 'Follow', 'Technology', 'Communication Equipment', '2,213'],
#  ['AAON', 'Follow', 'Industrials', 'Building Products & Equipment', '3,666'],
#  ['AAPL', 'Follow', 'Technology', 'Consumer Electronics', '164,000'],
#  ['ABCB', 'Follow', 'Financial Services', 'Banks—Regional', '2,847'],
#  ['ABCL', 'Follow', 'Healthcare', 'Biotechnology', '495']]

# %%
len(li)
# Out:
# 10

# %%
temp_df = pd.DataFrame(li, columns=["Symbol", "Foll", "Sector", "Industry", "Company Size"])

temp_df.drop(columns="Foll", inplace=True)
temp_df
# Out:
#   Symbol              Sector                       Industry Company Size
# 0   AACG  Consumer Defensive  Education & Training Services          536
# 1   AACI  Financial Services                Shell Companies
# 2   AADI          Healthcare                  Biotechnology           79
# 3    AAL         Industrials                       Airlines      129,700
# 4   AAME  Financial Services                 Insurance—Life          138
# 5   AAOI          Technology        Communication Equipment        2,213
# 6   AAON         Industrials  Building Products & Equipment        3,666
# 7   AAPL          Technology           Consumer Electronics      164,000
# 8   ABCB  Financial Services                 Banks—Regional        2,847
# 9   ABCL          Healthcare                  Biotechnology          495

# %%
temp_df.describe(include="all")
# Out:
#        Symbol              Sector       Industry Company Size
# count      10                  10             10           10
# unique     10                   5              9           10
# top      AACG  Financial Services  Biotechnology          536
# freq        1                   3              2            1

# %%
for i in range(len(temp_df)):
    
    if pd.notna(temp_df["Company Size"].iloc[i]):
        if ',' in temp_df["Company Size"].iloc[i]:
            temp_df["Company Size"].iloc[i] = temp_df["Company Size"].iloc[i].replace(',', '')
    else:
        temp_df["Company Size"].iloc[i] = 0

# %%
temp_df
# Out:
#   Symbol              Sector                       Industry Company Size
# 0   AACG  Consumer Defensive  Education & Training Services          536
# 1   AACI  Financial Services                Shell Companies
# 2   AADI          Healthcare                  Biotechnology           79
# 3    AAL         Industrials                       Airlines       129700
# 4   AAME  Financial Services                 Insurance—Life          138
# 5   AAOI          Technology        Communication Equipment         2213
# 6   AAON         Industrials  Building Products & Equipment         3666
# 7   AAPL          Technology           Consumer Electronics       164000
# 8   ABCB  Financial Services                 Banks—Regional         2847
# 9   ABCL          Healthcare                  Biotechnology          495

# %%
temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Symbol        10 non-null     object
#  1   Sector        10 non-null     object
#  2   Industry      10 non-null     object
#  3   Company Size  10 non-null     object
# dtypes: object(4)
# memory usage: 448.0+ bytes

# %%
temp_df = pd.read_csv("Generated Files\\stock-Detail-Files.csv")
temp_df
# Out:
#      Symbol              Sector                                Industry  \
# 0      AACG  Consumer Defensive           Education & Training Services
# 1      AACI  Financial Services                         Shell Companies
# 2      AADI          Healthcare                           Biotechnology
# 3       AAL         Industrials                                Airlines
# 4      AAME  Financial Services                          Insurance—Life
# ...     ...                 ...                                     ...
# 3576   ZVRA          Healthcare                           Biotechnology
# 3577   ZVSA          Healthcare                           Biotechnology
# 3578   ZYME          Healthcare                           Biotechnology
# 3579   ZYNE          Healthcare  Drug Manufacturers—Specialty & Generic
# 3580   ZYXI          Healthcare                    Medical Distribution
#
#       Company Size
# 0            536.0
# 1              NaN
# 2             79.0
# 3         129700.0
# ...

# %%
temp_df.describe(include="all")
# Out:
#        Symbol      Sector       Industry  Company Size
# count    3581        3576           3576  3.000000e+03
# unique   3581          11            139           NaN
# top      AACG  Healthcare  Biotechnology           NaN
# freq        1        1117            704           NaN
# mean      NaN         NaN            NaN  4.939212e+03
# std       NaN         NaN            NaN  3.557940e+04
# min       NaN         NaN            NaN  0.000000e+00
# 25%       NaN         NaN            NaN  8.100000e+01
# 50%       NaN         NaN            NaN  3.320000e+02
# 75%       NaN         NaN            NaN  1.779500e+03
# max       NaN         NaN            NaN  1.541000e+06

# %%
# temp_df.to_csv("Generated Files\\stock-Detail-Files.csv", index=False)
